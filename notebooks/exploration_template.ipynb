# %% [markdown]
# # MiDRR-Classifier — Exploratory Data Analysis
#
# **Project:** Minecraft as a Platform for AI-Enhanced Disaster Risk Simulation and Adaptive Educational Preparedness
# **Purpose:** Quick-start notebook for exploring raw gameplay logs and the engineered feature table.
#
# > **How to use:** Replace the placeholder file paths below with your actual data files and run all cells.
# > This notebook is intentionally lightweight — add visualisations and analyses as the dataset grows.

# %%
import sys
sys.path.insert(0, '../src')  # Ensure the package is importable without install

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from midrr_classifier.config import load_config
from midrr_classifier.data_ingestion import load_raw_logs
from midrr_classifier.feature_engineering import build_feature_table

cfg = load_config()  # uses default paths
print('Config loaded:', cfg)

# %% [markdown]
# ## 1. Load Raw Logs
#
# Replace `RAW_CSV_PATH` with the actual path to your raw gameplay CSV export.

# %%
RAW_CSV_PATH = 'data/raw/gameplay_logs.csv'  # TODO: replace with real path

# raw_df = load_raw_logs(RAW_CSV_PATH)   # uncomment when data is available
# raw_df.head()

print(f'[stub] Would load raw logs from: {RAW_CSV_PATH}')

# %%
# raw_df.describe()
# raw_df.info()
print('[stub] Describe and info calls go here once data is loaded.')

# %% [markdown]
# ## 2. Build Feature Table

# %%
# feature_df = build_feature_table(raw_df)  # uncomment when data is available
# feature_df.head()

print('[stub] Feature table will be built here once raw_df is available.')

# %% [markdown]
# ## 3. Class Distribution

# %%
# Uncomment after build_feature_table is called:
#
# counts = feature_df['preparedness_level'].value_counts()
# fig, ax = plt.subplots(figsize=(5, 3))
# counts.plot(kind='bar', ax=ax, color=['#2ecc71', '#f39c12', '#e74c3c'])
# ax.set_title('Preparedness Level Distribution')
# ax.set_xlabel('Level')
# ax.set_ylabel('Count')
# plt.tight_layout()
# plt.show()

print('[stub] Class distribution bar chart goes here.')

# %% [markdown]
# ## 4. Feature Correlation Heatmap

# %%
FEATURE_COLS = [
    'evacuation_time', 'decision_delay', 'path_efficiency_ratio',
    'hazard_avoidance_ratio', 'interaction_frequency', 'panic_proxy',
]

# Uncomment after feature_df is available:
#
# fig, ax = plt.subplots(figsize=(7, 5))
# sns.heatmap(feature_df[FEATURE_COLS].corr(), annot=True, fmt='.2f',
#             cmap='coolwarm', ax=ax)
# ax.set_title('Feature Correlation Matrix')
# plt.tight_layout()
# plt.show()

print('[stub] Correlation heatmap goes here.')

# %% [markdown]
# ---
# > **Next steps:** Save `feature_df` to `data/processed/features.csv`, then run `python -m midrr_classifier.train`.
